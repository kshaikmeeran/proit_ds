# %% [markdown]
# # DATA PREPARATION/DATA PREPROCESSING
#
# ### 3 Step Approach:
#
# **Step 1: Data Cleaning - drop, dropna. Mean, Median, mode Imputation (or) Any Value Imputation for Nan Values.**
#
# **Step 2: Data Type Convertion(Optional)**
#
# **Step 3: Data Transformation**

# %% [markdown]
# # 1. Import Necessary libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Import Data

# %%
weather_report_2010 = pd.read_csv('data_clean.csv')
weather_report_2010
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# # 3. Data Understanding

# %%
weather_report_2010.shape
# Out:
# (158, 10)

# %%
weather_report_2010.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
weather_report_2010['Ozone'].mean(),weather_report_2010['Ozone'].median()
# Out:
# (41.583333333333336, 30.5)

# %%
weather_report_2010['Weather'].value_counts()
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64

# %%
weather_report_2010.head(30)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1            2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2            3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3            4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4            5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6            7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7            8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8            9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9           10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10          11    7.0      NaN   6.9      C     5   11  2010    74       C
# ...

# %%
weather_report_2010.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# # 4. Data Preparation

# %% [markdown]
# ### STEP 1: Data Cleaning

# %% [markdown]
# ## Client, Deepak agrees to drop the entire feature Ozone.

# %%
weather_report_2010.drop(labels = ['Unnamed: 0','Ozone'],axis=1,inplace=True)

# %%
weather_report_2010.isna().sum()
# Out:
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
7/158
# Out:
# 0.04430379746835443

# %%
weather_report_2010['Solar.R'].mean()
# Out:
# 185.40397350993376

# %%
weather_report_2010['Solar.R'].median()
# Out:
# 197.0

# %% [markdown]
# ### =============================================TRY IT=====================================

# %% [markdown]
# Sir, Can't we replace the Ozone using groupby func. for each weather condition.. Below are the mean values for each weather condition.
#
# C     46.162162
#
# PS    42.194444
#
# S     36.909091

# %% [markdown]
# ### ======================================================================================

# %%
weather_report_2010.groupby(by = 'Weather')['Solar.R'].mean()
# Out:
# Weather
# C     192.391304
# PS    174.347826
# S     193.333333
# Name: Solar.R, dtype: float64

# %%
weather_report_2010_S = weather_report_2010[weather_report_2010['Weather'] == 'S']
weather_report_2010_S['Solar.R'].fillna(193.3,inplace=True)
weather_report_2010_S
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 96     190.0   7.4      5    1  2010    67       S
# 97     313.0  11.5      5    4  2010    62       S
# 98     193.3  14.3      5    5  2010    56       S
# 99     194.0   8.6      5   10  2010    69       S
# 100    290.0   9.2      5   13  2010    66       S
# 101    274.0  10.9      5   14  2010    68       S
# 102    334.0  11.5      5   16  2010    64       S
# 103    307.0  12.0      5   17  2010    66       S
# 104     44.0   9.7      5   20  2010    62       S
# 105      8.0   9.7      5   21  2010    59       S
# 106     13.0  12.0      5   28  2010    67       S
# 107    252.0  14.9      5   29  2010    81       S
# 108    286.0   8.6      6    1  2010    78       S
# 109    273.0   6.9      6    8  2010    87       S
# 110    291.0  13.8      6    9  2010    90       S
# 111    323.0  11.5      6   10  2010    87       S
# 112    148.0   8.0      6   13  2010    82       S
# ...

# %%
weather_report_2010_PS = weather_report_2010[weather_report_2010['Weather'] == 'PS']
weather_report_2010_PS['Solar.R'].fillna(174.3,inplace=True)
weather_report_2010_PS
# Out:
#     Solar.R  Wind  Month  Day  Year  Temp Weather
# 49    149.0  12.6      5    3  2010    74      PS
# 50    299.0   8.6      5    7  2010    65      PS
# 51     19.0  20.1      5    9  2010    61      PS
# 52    256.0   9.7      5   12  2010    69      PS
# 53    322.0  11.5      5   19  2010    68      PS
# 54     25.0   9.7      5   23  2010    61      PS
# 55     66.0  16.6      5   25  2010    57      PS
# 56    174.3   8.0      5   27  2010    57      PS
# 57    279.0   7.4      5   31  2010    76      PS
# 58    242.0  16.1      6    3  2010    67      PS
# 59    220.0   8.6      6    5  2010    85      PS
# 60    127.0   9.7      6    7  2010    82      PS
# 61    250.0   9.2      6   12  2010    92      PS
# 62    191.0  14.9      6   16  2010    77      PS
# 63     37.0   9.2      6   18  2010    65      PS
# 64     91.0   4.6      6   23  2010    76      PS
# 65    127.0   8.0      6   26  2010    78      PS
# 66     98.0  11.5      6   28  2010    80      PS
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
weather_data_2010_C = weather_report_2010[weather_report_2010['Weather'] == 'C']
weather_data_2010_C['Solar.R'].fillna(192.4,inplace=True)
weather_data_2010_C
# Out:
#      Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1      118.0   8.0     72     5    2  2010    72       C
# 5      192.4  14.9     66     5    6  2010    66       C
# 7       99.0  13.8     59     5    8  2010    59       C
# 10     192.4   6.9      C     5   11  2010    74       C
# 14      65.0  13.2     58     5   15  2010    58       C
# 17      78.0  18.4     57     5   18  2010    57       C
# 21     320.0  16.6     73     5   22  2010    73       C
# 23      92.0  12.0     61   May   24  2010    61       C
# 25     266.0  14.9     58     5   26  2010    58       C
# 29     223.0   5.7     79     5   30  2010    79       C
# 32     287.0   9.7     74     6    2  2010    74       C
# 34     186.0   9.2     84     6    4  2010    84       C
# 36     264.0  14.3     79     6    6  2010    79       C
# 41     259.0  10.9     93     6   11  2010    93       C
# 45     322.0  11.5     79     6   15  2010    79       C
# ...

# %%
weather_report_2010 = pd.concat([weather_data_2010_C,weather_report_2010_PS,weather_report_2010_S])
weather_report_2010 = weather_report_2010.reset_index()
weather_report_2010
# Out:
#      index  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0        1    118.0   8.0     72     5    2  2010    72       C
# 1        5    192.4  14.9     66     5    6  2010    66       C
# 2        7     99.0  13.8     59     5    8  2010    59       C
# 3       10    192.4   6.9      C     5   11  2010    74       C
# 4       14     65.0  13.2     58     5   15  2010    58       C
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 150    145    139.0  10.3     81     9   23  2010    81       S
# 151    150    191.0  14.3     75     9   28  2010    75       S
# 152    152    223.0  11.5     68     9   30  2010    68       S
# 153    155    145.0  13.2     77     9   27  2010    77       S
# 154    156    191.0  14.3     75     9   28  2010    75       S
#
# [155 rows x 9 columns]

# %%
del weather_report_2010['index']

# %%
weather_report_2010.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_report_2010.shape
# Out:
# (155, 8)

# %%
weather_report_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
del weather_report_2010['Temp C']

# %%
weather_report_2010.head(30)
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 0     118.0   8.0     5    2  2010    72       C
# 1     192.4  14.9     5    6  2010    66       C
# 2      99.0  13.8     5    8  2010    59       C
# 3     192.4   6.9     5   11  2010    74       C
# 4      65.0  13.2     5   15  2010    58       C
# 5      78.0  18.4     5   18  2010    57       C
# 6     320.0  16.6     5   22  2010    73       C
# 7      92.0  12.0   May   24  2010    61       C
# 8     266.0  14.9     5   26  2010    58       C
# 9     223.0   5.7     5   30  2010    79       C
# 10    287.0   9.7     6    2  2010    74       C
# 11    186.0   9.2     6    4  2010    84       C
# 12    264.0  14.3     6    6  2010    79       C
# 13    259.0  10.9     6   11  2010    93       C
# 14    322.0  11.5     6   15  2010    79       C
# 15    284.0  20.7     6   17  2010    72       C
# 16     59.0   1.7     6   22  2010    76       C
# 17    135.0   8.0     6   25  2010    75       C
# ...

# %%
weather_report_2010[weather_report_2010['Month'] == 'May'] = weather_report_2010[weather_report_2010['Month'] == 'May'].replace('May',5)

# %%
weather_report_2010.head(10)
# Out:
#    Solar.R  Wind Month  Day  Year  Temp Weather
# 0    118.0   8.0     5    2  2010    72       C
# 1    192.4  14.9     5    6  2010    66       C
# 2     99.0  13.8     5    8  2010    59       C
# 3    192.4   6.9     5   11  2010    74       C
# 4     65.0  13.2     5   15  2010    58       C
# 5     78.0  18.4     5   18  2010    57       C
# 6    320.0  16.6     5   22  2010    73       C
# 7     92.0  12.0     5   24  2010    61       C
# 8    266.0  14.9     5   26  2010    58       C
# 9    223.0   5.7     5   30  2010    79       C

# %%
weather_report_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_report_2010.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# ## Step 2: Data Type Convertion

# %%
weather_report_2010['Month'] = weather_report_2010['Month'].astype('int')

# %%
weather_report_2010.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_report_2010.head()
# Out:
#    Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    118.0   8.0      5    2  2010    72       C
# 1    192.4  14.9      5    6  2010    66       C
# 2     99.0  13.8      5    8  2010    59       C
# 3    192.4   6.9      5   11  2010    74       C
# 4     65.0  13.2      5   15  2010    58       C

# %% [markdown]
# ## Step3: Data Transformation

# %% [markdown]
# ### 2 Transformation Techniques: Discrete Vs Continous
#
# **1. Discrete - Label Encoding/One Hot Encoding**
#
# **2. Continous - MinMax Scaler/Standard Scaler/Robust Scaler**

# %% [markdown]
# ## 1. Use Label Encoding

# %%
weather_report_2010_2 = weather_report_2010.copy()
weather_report_2010_2
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 0      118.0   8.0      5    2  2010    72       C
# 1      192.4  14.9      5    6  2010    66       C
# 2       99.0  13.8      5    8  2010    59       C
# 3      192.4   6.9      5   11  2010    74       C
# 4       65.0  13.2      5   15  2010    58       C
# ..       ...   ...    ...  ...   ...   ...     ...
# 150    139.0  10.3      9   23  2010    81       S
# 151    191.0  14.3      9   28  2010    75       S
# 152    223.0  11.5      9   30  2010    68       S
# 153    145.0  13.2      9   27  2010    77       S
# 154    191.0  14.3      9   28  2010    75       S
#
# [155 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
weather_report_2010_2['Weather'] = le.fit_transform(weather_report_2010_2['Weather'])
weather_report_2010_2
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0      118.0   8.0      5    2  2010    72        0
# 1      192.4  14.9      5    6  2010    66        0
# 2       99.0  13.8      5    8  2010    59        0
# 3      192.4   6.9      5   11  2010    74        0
# 4       65.0  13.2      5   15  2010    58        0
# ..       ...   ...    ...  ...   ...   ...      ...
# 150    139.0  10.3      9   23  2010    81        2
# 151    191.0  14.3      9   28  2010    75        2
# 152    223.0  11.5      9   30  2010    68        2
# 153    145.0  13.2      9   27  2010    77        2
# 154    191.0  14.3      9   28  2010    75        2
#
# [155 rows x 7 columns]

# %%
weather_report_2010_2.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather      int32
# dtype: object

# %% [markdown]
# ## 2. Using OneHot Encoder
#
# It can be built by using 2 libraries:
#
# 1. sklearn - OneHotEncoder()
# 2. Pandas  - pd.get_dummies()

# %%
weather_report_2010_3 = weather_report_2010.copy()
weather_report_2010_3
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 0      118.0   8.0      5    2  2010    72       C
# 1      192.4  14.9      5    6  2010    66       C
# 2       99.0  13.8      5    8  2010    59       C
# 3      192.4   6.9      5   11  2010    74       C
# 4       65.0  13.2      5   15  2010    58       C
# ..       ...   ...    ...  ...   ...   ...     ...
# 150    139.0  10.3      9   23  2010    81       S
# 151    191.0  14.3      9   28  2010    75       S
# 152    223.0  11.5      9   30  2010    68       S
# 153    145.0  13.2      9   27  2010    77       S
# 154    191.0  14.3      9   28  2010    75       S
#
# [155 rows x 7 columns]

# %% [markdown]
# #### 2.1 Using Pandas

# %%
weather_report_2010_3 = pd.get_dummies(data = weather_report_2010_3,columns=['Weather'])
weather_report_2010_3
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  Weather_S
# 0      118.0   8.0      5    2  2010    72       True       False      False
# 1      192.4  14.9      5    6  2010    66       True       False      False
# 2       99.0  13.8      5    8  2010    59       True       False      False
# 3      192.4   6.9      5   11  2010    74       True       False      False
# 4       65.0  13.2      5   15  2010    58       True       False      False
# ..       ...   ...    ...  ...   ...   ...        ...         ...        ...
# 150    139.0  10.3      9   23  2010    81      False       False       True
# 151    191.0  14.3      9   28  2010    75      False       False       True
# 152    223.0  11.5      9   30  2010    68      False       False       True
# 153    145.0  13.2      9   27  2010    77      False       False       True
# 154    191.0  14.3      9   28  2010    75      False       False       True
#
# [155 rows x 9 columns]

# %%
weather_report_2010_3.dtypes
# Out:
# Solar.R       float64
# Wind          float64
# Month           int32
# Day             int64
# Year            int64
# Temp            int64
# Weather_C        bool
# Weather_PS       bool
# Weather_S        bool
# dtype: object

# %% [markdown]
# #### 2.2 Using Sklearn

# %%
weather_report_2010_4 = weather_report_2010.copy()
weather_report_2010_4
# Out:
#      Solar.R  Wind  Month  Day  Year  Temp Weather
# 0      118.0   8.0      5    2  2010    72       C
# 1      192.4  14.9      5    6  2010    66       C
# 2       99.0  13.8      5    8  2010    59       C
# 3      192.4   6.9      5   11  2010    74       C
# 4       65.0  13.2      5   15  2010    58       C
# ..       ...   ...    ...  ...   ...   ...     ...
# 150    139.0  10.3      9   23  2010    81       S
# 151    191.0  14.3      9   28  2010    75       S
# 152    223.0  11.5      9   30  2010    68       S
# 153    145.0  13.2      9   27  2010    77       S
# 154    191.0  14.3      9   28  2010    75       S
#
# [155 rows x 7 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe.fit_transform(weather_report_2010_4['Weather'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 ohe = OneHotEncoder()
# ----> 3 ohe.fit_transform(weather_report_2010_4['Weather'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
#     277             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     278             *data_to_wrap[1:],
#     279         )
#
# ...

# %% [markdown]
# ## =====================================================================

# %% [markdown]
# ## How to choose between OHE and LE????

# %% [markdown]
# ### Input feature:
# Based on whether it is **Parametric or a Non Parametric Model**, we will choosing between LE or OHE.
# * For **Parametric Models** - better to go with **OHE.**
# * For **Non-Parametric Models** - always go with **Label Encoding.**
#
# ### Output feature:
# Always the output feature, it must be **Label Encoder.**

# %% [markdown]
# ## =====================================================================
