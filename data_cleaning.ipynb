# %%
import pandas as pd

# %%
sales_2017 = pd.read_csv('Sales Transactions-2017.csv')
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2018 = pd.read_csv('Sales Transactions-2018.csv')
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2019 = pd.read_csv('Sales Transactions-2019.csv')
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
total_sales = pd.concat([sales_2017,sales_2018,sales_2019])
total_sales
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
total_sales.shape
# Out:
# (111206, 9)

# %%
total_sales.head()
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
total_sales.tail()
# Out:
#              Date   Voucher      Party         Product           Qty  \
# 19171  10/10/2019  Sal:4935  K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN        NaN             NaN           NaN
# 19173         NaN       NaN        NaN             NaN           NaN
# 19174         NaN   Total          NaN             NaN     99,284.90
# 19175         NaN   Total          NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# 19171            16       6,400.00         NaN            NaN
# 19172           NaN            NaN         NaN            NaN
# 19173           NaN            NaN         NaN            NaN
# 19174    175,381.65   2,203,649.50   20,680.00   2,189,014.50
# 19175  5,519,888.40  53,360,791.40  672,984.00  52,830,224.40

# %%
total_sales.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
total_sales.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
total_sales.describe()
# Out:
#          Date Voucher   Party Product    Qty   Rate  Gross  Disc  \
# count   98615   98649  111166   98615  98649  98648  98648  5597
# unique    836   10044    1994     867    546   1109   2548   371
# top                      TP13            100
# freq     3053    3053   13056    3053  12528   3051   3053  3053
#
#        Voucher Amount
# count           27560
# unique           7149
# top
# freq             3053

# %%
total_sales_cleaned = pd.read_csv('Sales-Transactions-Edited.csv')

# %%
total_sales_cleaned.dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
total_sales_cleaned
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
total_sales = total_sales.drop_duplicates()

# %%
total_sales = total_sales.drop_duplicates()

# %%
total_sales.isna().sum()
# Out:
# Date                204
# Voucher             170
# Party                35
# Product             204
# Qty                 170
# Rate                171
# Gross               171
# Disc              92951
# Voucher Amount    70984
# dtype: int64

# %%
total_sales = total_sales.drop(columns = ['Gross','Disc','Voucher Amount'])

# %%
total_sales
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate
# 0                 2      1,690.00
# 1                 6      1,620.00
# ...

# %%
total_sales['Voucher'] = total_sales['Voucher'].str.replace("Sal:","",n=-1)

# %%
total_sales
# Out:
#              Date  Voucher               Party              Product  \
# 0        1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...      ...                 ...                  ...
# 19169  10/10/2019     4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019     4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019     4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN  Total                   NaN                  NaN
# 19175         NaN  Total                   NaN                  NaN
#
#                 Qty          Rate
# 0                 2      1,690.00
# 1                 6      1,620.00
# 2               500            23
# ...

# %%
total_sales.fillna('')
# Out:
#              Date  Voucher               Party              Product  \
# 0        1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...      ...                 ...                  ...
# 19169  10/10/2019     4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019     4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019     4935           K.SRIHARI       13*16 WHITE RK
# 19174              Total
# 19175              Total
#
#                 Qty          Rate
# 0                 2      1,690.00
# 1                 6      1,620.00
# 2               500            23
# 3                 6      1,620.00
# 4                 5      1,690.00
# ...

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
total_sales.isna().sum()
# Out:
# Date       204
# Voucher    170
# Party       35
# Product    204
# Qty        170
# Rate       171
# dtype: int64

# %%
total_sales_cleaned
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
total_sales_cleaned.dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
#for x in total_sales.index:
 #   if total_sales.loc[x,"Voucher"] == 'Total':
  #      total_sales.drop(x,inplace = True)
        
#total_sales

# %%
total_sales.dropna(subset = "Date",inplace = True)

# %%
total_sales
# Out:
#              Date Voucher               Party              Product  Qty  \
# 0        1/4/2017       1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017       1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017       2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017       2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017       2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...     ...                 ...                  ...  ...
# 19167  10/10/2019    4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019    4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019    4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019    4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019    4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# 3      1,620.00
# ...

# %%
total_sales.dropna()
# Out:
#              Date Voucher               Party              Product  Qty  \
# 0        1/4/2017       1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017       1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017       2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017       2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017       2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...     ...                 ...                  ...  ...
# 19167  10/10/2019    4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019    4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019    4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019    4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019    4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# 3      1,620.00
# ...

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
total_sales.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# dtype: int64

# %%
total_sales = total_sales.reset_index(drop = True)

# %%
total_sales
# Out:
#              Date Voucher               Party              Product  Qty  \
# 0        1/4/2017       1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017       1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017       2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017       2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017       2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...     ...                 ...                  ...  ...
# 96415  10/10/2019    4935           K.SRIHARI         16*20(100-W)  140
# 96416  10/10/2019    4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 96417  10/10/2019    4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 96418  10/10/2019    4935           K.SRIHARI             10*12 RK  800
# 96419  10/10/2019    4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# 3      1,620.00
# ...

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
total_sales.reset_index(level= 0,inplace = True)

# %%
total_sales['index']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 96415    96415
# 96416    96416
# 96417    96417
# 96418    96418
# 96419    96419
# Name: index, Length: 96420, dtype: int64

# %%
total_sales.reset_index(level=0, inplace=True)

# %%
total_sales
# Out:
#        level_0  index        Date Voucher               Party  \
# 0            0      0    1/4/2017       1    SOLANKI PLASTICS
# 1            1      1    1/4/2017       1    SOLANKI PLASTICS
# 2            2      2    1/4/2017       2  SARNESWARA TRADERS
# 3            3      3    1/4/2017       2  SARNESWARA TRADERS
# 4            4      4    1/4/2017       2  SARNESWARA TRADERS
# ...        ...    ...         ...     ...                 ...
# 96415    96415  96415  10/10/2019    4935           K.SRIHARI
# 96416    96416  96416  10/10/2019    4935           K.SRIHARI
# 96417    96417  96417  10/10/2019    4935           K.SRIHARI
# 96418    96418  96418  10/10/2019    4935           K.SRIHARI
# 96419    96419  96419  10/10/2019    4935           K.SRIHARI
#
#                    Product  Qty      Rate
# 0            DONA-VAI-9100    2  1,690.00
# 1          LITE FOAM(1200)    6  1,620.00
# 2        VISHNU CHOTA WINE  500        23
# 3          LITE FOAM(1200)    6  1,620.00
# ...

# %%
total_sales = total_sales.drop(columns = ['index'])

# %%
total_sales=total_sales.drop(columns = ['level_0'])
total_sales
# Out:
#              Date Voucher               Party              Product  Qty  \
# 0        1/4/2017       1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017       1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017       2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017       2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017       2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...     ...                 ...                  ...  ...
# 96415  10/10/2019    4935           K.SRIHARI         16*20(100-W)  140
# 96416  10/10/2019    4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 96417  10/10/2019    4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 96418  10/10/2019    4935           K.SRIHARI             10*12 RK  800
# 96419  10/10/2019    4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# 3      1,620.00
# ...

# %%
total_sales[total_sales['Rate'].isna()==1]
# Out:
#            Date Voucher     Party            Product Qty Rate
# 37970  5/3/2018    9266  CUSTOMER  TIRML-BL-KG-17*23   2  NaN

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
total_sales['Rate'].fillna('')
# Out:
# 0        1,690.00
# 1        1,620.00
# 2              23
# 3        1,620.00
# 4        1,690.00
#            ...
# 96415          26
# 96416         8.4
# 96417          16
# 96418         8.5
# 96419          16
# Name: Rate, Length: 96420, dtype: object

# %%
total_sales[total_sales['Rate'].isna()==1]
# Out:
#            Date Voucher     Party            Product Qty Rate
# 37970  5/3/2018    9266  CUSTOMER  TIRML-BL-KG-17*23   2  NaN

# %%
total_sales['Rate'] = total_sales['Rate'].fillna(0)

# %%
total_sales['Rate'].dtypes
# Out:
# dtype('O')

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
float(total_sales['Rate'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 float(total_sales['Rate'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:230, in _coerce_method.<locals>.wrapper(self)
#     222     warnings.warn(
#     223         f"Calling {converter.__name__} on a single element Series is "
#     224         "deprecated and will raise a TypeError in the future. "
#    (...)
#     227         stacklevel=find_stack_level(),
#     228     )
#     229     return converter(self.iloc[0])
# --> 230 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
total_sales[total_sales['Voucher']== '9266']

# %%
#weather["Temp"] = weather["Temp"].convert_objects(convert_numeric=True)
#df['col name']=df.col name .astype(float)

total_sales['Voucher'] = total_sales['Voucher'].astype(float)

# %%
total_sales

# %%
total_sales[total_sales['Voucher'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Date, Voucher, Party, Product, Qty, Rate]
# Index: []

# %%
total_sales.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# dtype: int64

# %%
total_sales.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
pd.to_numeric(total_sales['Rate'], errors='coerce').fillna(0, downcast='infer')
# Out:
# 0         0.0
# 1         0.0
# 2        23.0
# 3         0.0
# 4         0.0
#          ...
# 96415    26.0
# 96416     8.4
# 96417    16.0
# 96418     8.5
# 96419    16.0
# Name: Rate, Length: 96420, dtype: float64

# %%
total_sales['Rate']=total_sales['Rate'].loc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 total_sales['Rate']=total_sales['Rate'].loc.astype('float')
#
# AttributeError: '_LocIndexer' object has no attribute 'astype'

# %%
total_sales_cleaned.dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
type(total_sales['Rate'])
# Out:
# pandas.core.series.Series

# %%
total_sales.columns
# Out:
# Index(['Date', 'Voucher', 'Party', 'Product', 'Qty', 'Rate'], dtype='object')

# %%
total_sales[['Rate','Qty']].describe()
# Out:
#          Rate    Qty
# count   96420  96420
# unique   1076    512
# top        26    100
# freq     2730  12459
