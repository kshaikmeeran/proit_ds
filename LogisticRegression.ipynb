# %%
import pandas as pd
# Out:
# C:\Users\Nasir\AppData\Local\Temp\ipykernel_3024\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("weight-height.csv")

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
x=df.drop(labels="Gender",axis=1)

# %%
x
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
y=df[["Gender"]]

# %%
y
# Out:
#       Gender
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 9995  Female
# 9996  Female
# 9997  Female
# 9998  Female
# 9999  Female
#
# [10000 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(x,y)
# Out:
# C:\Users\Nasir\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
df["Pred"]=model.predict(x)

# %%
df
# Out:
#       Gender     Height      Weight    Pred
# 0       Male  73.847017  241.893563    Male
# 1       Male  68.781904  162.310473  Female
# 2       Male  74.110105  212.740856    Male
# 3       Male  71.730978  220.042470    Male
# 4       Male  69.881796  206.349801    Male
# ...      ...        ...         ...     ...
# 9995  Female  66.172652  136.777454  Female
# 9996  Female  67.067155  170.867906    Male
# 9997  Female  63.867992  128.475319  Female
# 9998  Female  69.034243  163.852461  Female
# 9999  Female  61.944246  113.649103  Female
#
# [10000 rows x 4 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(df["Gender"],df["Pred"])
# Out:
# 0.9195
